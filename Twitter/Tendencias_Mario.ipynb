# %%
import pandas as pd

# %%
df = pd.read_csv("totales_historicos.csv")

# %%
df
# Out:
#                  created_at  \
# 0       2020-05-20 18:22:39
# 1       2020-05-20 18:22:39
# 2       2020-05-20 18:22:39
# 3       2020-05-20 18:22:40
# 4       2020-05-20 18:22:40
# ...                     ...
# 249995  2020-05-24 21:53:11
# 249996  2020-05-24 21:53:12
# 249997  2020-05-24 21:53:13
# 249998  2020-05-24 21:53:13
# 249999  2020-05-24 21:53:15
#
#                                                      text  \
# 0       Un poquito de mi oaxaca. @MezcalConvite https:...
# 1                         @ramonpenafranco Si bien les va
# 2       Acaba de publicar una foto en Copiadoras Delta...
# 3       When the servers are down but somehow I can ge...
# 4       #ÚltimaHora | Este año la peregrinación de #Qu...
# ...                                                   ...
# 249995                    @yahirecheverria No es eso mano
# 249996  De expedición fotográfica por los terrenos del...
# 249997                @nelatoodope bitch I miss you too 🥺
# 249998  X eso no hablo con ex’s se les olvida cuando t...
# 249999         I hate coming home to an unexpected period
#
#                                               coordinates  \
# 0                                                     NaN
# 1                                                     NaN
# 2       {'type': 'Point', 'coordinates': [-98.8841629,...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 249995                                                NaN
# 249996  {'type': 'Point', 'coordinates': [-103.3400210...
# 249997                                                NaN
# 249998                                                NaN
# 249999                                                NaN
#
#                                                  hashtags
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4       [{'text': 'ÚltimaHora', 'indices': [0, 11]}, {...
# ...                                                   ...
# 249995                                                 []
# 249996                                                 []
# 249997                                                 []
# 249998                                                 []
# 249999                                                 []
#
# [250000 rows x 4 columns]

# %%
candidatos = [True if ('unam' in tweet.lower()) or ('virus' in tweet.lower()) or ('hospital' in tweet.lower())
             or ('covid-19' in tweet.lower()) else False for tweet in df['text']]

# %%
muestra = df[candidatos]

# %%
ignore = ["a","actualmente","acuerdo","adelante","ademas","además","adrede","afirmó","agregó","ahi","ahora","ahí","al","algo","alguna","algunas","alguno","algunos","algún","alli","allí","alrededor","ambos","ampleamos","antano","antaño","ante","anterior","antes","apenas","aproximadamente","aquel","aquella","aquellas","aquello","aquellos","aqui","aquél","aquélla","aquéllas","aquéllos","aquí","arriba","arribaabajo","aseguró","asi","así","atras","aun","aunque","ayer","añadió","aún","b","bajo","bastante","bien","breve","buen","buena","buenas","bueno","buenos","c","cada","casi","cerca","cierta","ciertas","cierto","ciertos","cinco","claro","comentó","como","con","conmigo","conocer","conseguimos","conseguir","considera","consideró","consigo","consigue","consiguen","consigues","contigo","contra","cosas","creo","cual","cuales","cualquier","cuando","cuanta","cuantas","cuanto","cuantos","cuatro","cuenta","cuál","cuáles","cuándo","cuánta","cuántas","cuánto","cuántos","cómo","d","da","dado","dan","dar","de","debajo","debe","deben","debido","decir","dejó","del","delante","demasiado","demás","dentro","deprisa","desde","despacio","despues","después","detras","detrás","dia","dias","dice","dicen","dicho","dieron","diferente","diferentes","dijeron","dijo","dio","donde","dos","durante","día","días","dónde","e","ejemplo","el","ella","ellas","ello","ellos","embargo","empleais","emplean","emplear","empleas","empleo","en","encima","encuentra","enfrente","enseguida","entonces","entre","era","erais","eramos","eran","eras","eres","es","esa","esas","ese","eso","esos","esta","estaba","estabais","estaban","estabas","estad","estada","estadas","estado","estados","estais","estamos","estan","estando","estar","estaremos","estará","estarán","estarás","estaré","estaréis","estaría","estaríais","estaríamos","estarían","estarías","estas","este","estemos","esto","estos","estoy","estuve","estuviera","estuvierais","estuvieran","estuvieras","estuvieron","estuviese","estuvieseis","estuviesen","estuvieses","estuvimos","estuviste","estuvisteis","estuviéramos","estuviésemos","estuvo","está","estábamos","estáis","están","estás","esté","estéis","estén","estés","ex","excepto","existe","existen","explicó","expresó","f","fin","final","fue","fuera","fuerais","fueran","fueras","fueron","fuese","fueseis","fuesen","fueses","fui","fuimos","fuiste","fuisteis","fuéramos","fuésemos","g","general","gran","grandes","gueno","h","ha","haber","habia","habida","habidas","habido","habidos","habiendo","habla","hablan","habremos","habrá","habrán","habrás","habré","habréis","habría","habríais","habríamos","habrían","habrías","habéis","había","habíais","habíamos","habían","habías","hace","haceis","hacemos","hacen","hacer","hacerlo","haces","hacia","haciendo","hago","han","has","hasta","hay","haya","hayamos","hayan","hayas","hayáis","he","hecho","hemos","hicieron","hizo","horas","hoy","hube","hubiera","hubierais","hubieran","hubieras","hubieron","hubiese","hubieseis","hubiesen","hubieses","hubimos","hubiste","hubisteis","hubiéramos","hubiésemos","hubo","i","igual","incluso","indicó","informo","informó","intenta","intentais","intentamos","intentan","intentar","intentas","intento","ir","j","junto","k","l","la","lado","largo","las","le","lejos","les","llegó","lleva","llevar","lo","los","luego","lugar","m","mal","manera","manifestó","mas","mayor","me","mediante","medio","mejor","mencionó","menos","menudo","mi","mia","mias","mientras","mio","mios","mis","misma","mismas","mismo","mismos","modo","momento","mucha","muchas","mucho","muchos","muy","más","mí","mía","mías","mío","míos","n","nada","nadie","ni","ninguna","ningunas","ninguno","ningunos","ningún","no","nos","nosotras","nosotros","nuestra","nuestras","nuestro","nuestros","nueva","nuevas","nuevo","nuevos","nunca","o","ocho","os","otra","otras","otro","otros","p","pais","para","parece","parte","partir","pasada","pasado","paìs","peor","pero","pesar","poca","pocas","poco","pocos","podeis","podemos","poder","podria","podriais","podriamos","podrian","podrias","podrá","podrán","podría","podrían","poner","por","por qué","porque","posible","primer","primera","primero","primeros","principalmente","pronto","propia","propias","propio","propios","proximo","próximo","próximos","pudo","pueda","puede","pueden","puedo","pues","q","qeu","que","quedó","queremos","quien","quienes","quiere","quiza","quizas","quizá","quizás","quién","quiénes","qué","r","raras","realizado","realizar","realizó","repente","respecto","s","sabe","sabeis","sabemos","saben","saber","sabes","sal","salvo","se","sea","seamos","sean","seas","segun","segunda","segundo","según","seis","ser","sera","seremos","será","serán","serás","seré","seréis","sería","seríais","seríamos","serían","serías","seáis","señaló","si","sido","siempre","siendo","siete","sigue","siguiente","sin","sino","sobre","sois","sola","solamente","solas","solo","solos","somos","son","soy","soyos","su","supuesto","sus","suya","suyas","suyo","suyos","sé","sí","sólo","t","tal","tambien","también","tampoco","tan","tanto","tarde","te","temprano","tendremos","tendrá","tendrán","tendrás","tendré","tendréis","tendría","tendríais","tendríamos","tendrían","tendrías","tened","teneis","tenemos","tener","tenga","tengamos","tengan","tengas","tengo","tengáis","tenida","tenidas","tenido","tenidos","teniendo","tenéis","tenía","teníais","teníamos","tenían","tenías","tercera","ti","tiempo","tiene","tienen","tienes","toda","todas","todavia","todavía","todo","todos","total","trabaja","trabajais","trabajamos","trabajan","trabajar","trabajas","trabajo","tras","trata","través","tres","tu","tus","tuve","tuviera","tuvierais","tuvieran","tuvieras","tuvieron","tuviese","tuvieseis","tuviesen","tuvieses","tuvimos","tuviste","tuvisteis","tuviéramos","tuviésemos","tuvo","tuya","tuyas","tuyo","tuyos","tú","u","ultimo","un","una","unas","uno","unos","usa","usais","usamos","usan","usar","usas","uso","usted","ustedes","v","va","vais","valor","vamos","van","varias","varios","vaya","veces","ver","verdad","verdadera","verdadero","vez","vosotras","vosotros","voy","vuestra","vuestras","vuestro","vuestros","w","x","y","ya","yo","z","él","éramos","ésa","ésas","ése","ésos","ésta","éstas","éste","éstos","última","últimas","último","últimos", "el", "las", "más","mis","su","ante","ni","de","en","el","rt","la","que","a","y","por","to","|","the","of","in","and","is","-"]

# %%
import re

def obtenerTendencias(df_tweets, dia = None):
    if dia != None:
        filtro = [True if re.match(dia, fecha) != None else False for fecha in df_tweets["created_at"]]
        df_tweets = df_tweets[filtro]
    tendencias = {}

    for index, row in df_tweets.iterrows():
        for word_start in row['text'].split():
            word = word_start.lower()
            if word not in ignore:
                try:
                    tendencias[word] += 1 
                except:
                    tendencias[word] = 1
    return sorted(tendencias.items(), key=lambda tup: tup[1], reverse=True)

# %%
obtenerTendencias(muestra, dia="2020-05-24")
# Out:
# [('covid-19', 58),
#  ('coronavirus', 52),
#  ('virus', 40),
#  ('#coronavirus', 37),
#  ('casos', 32),
#  ('hospital', 26),
#  ('méxico', 16),
#  ('covid-19.', 14),
#  ('#covid19', 14),
#  ('hospitales', 14),
#  ('#actualización⭕|', 12),
#  ('@unam_mx', 11),
#  ('covid-19,', 11),
#  ('mil', 10),
#  ('🦠', 10),
#  ('this', 10),
#  ('vía', 9),
#  ('confirmados', 9),
#  ('23', 9),
#  ('mayo', 9),
#  ('on', 9),
#  ('so', 9),
#  ('you', 8),
#  ('was', 8),
#  ('corona', 8),
#  ('.', 8),
#  ('...', 7),
#  ('2020', 7),
#  ('contagios', 7),
#  ('be', 7),
#  ('de…', 6),
#  ('mundo', 6),
#  ('personas', 6),
#  ('supera', 6),
#  ('from', 6),
#  ('are', 6),
#  ('people', 6),
#  ('for', 6),
#  ('muertos', 6),
#  ('that', 6),
#  ('tiempos', 5),
#  ('#covid19.😷', 5),
#  ('#méxico', 5),
#  ('defunciones', 5),
#  ('virus,', 5),
#  ('llega', 5),
#  ('all', 5),
#  ('"covid-19:', 5),
#  ('@realdonaldtrump', 5),
#  ('my', 5),
#  ('with', 5),
#  ('what', 5),
#  ('we', 5),
#  ('dead', 5),
#  ('salud', 5),
#  ('❎', 5),
#  ('at', 4),
#  ('situación', 4),
#  ('años', 4),
#  ('#coronavirus…', 4),
#  ('#87punto3', 4),
#  ('|…', 4),
#  ('número', 4),
#  ('entidad', 4),
#  ('pandemia', 4),
#  ('atención', 4),
#  ('#covid-19', 4),
#  ('vacuna', 4),
#  ('china', 4),
#  ('alto', 4),
#  ('gente', 4),
#  ('positivos', 4),
#  ('d…', 4),
#  ('65', 4),
#  ('via', 4),
#  ('or', 4),
#  ('t…', 4),
#  ('muertes', 4),
#  ('out', 4),
#  ('100k', 4),
#  ('covid', 4),
#  ('learn', 4),
#  ('#sabadodecuarentena', 4),
#  ('amlo', 4),
#  ('veo', 4),
#  ('realidad', 4),
#  ('#covidー19', 4),
#  ('vida', 4),
#  ('unam', 4),
#  ('ojalá', 4),
#  ('new', 4),
#  ('querétaro', 4),
#  ('virus.', 4),
#  ('familia', 4),
#  ('would', 4),
#  ('pandemic', 4),
#  ('presidente', 3),
#  ('e…', 3),
#  ('conferencia', 3),
#  ('nacional', 3),
#  ('#noticias', 3),
#  ('actualización', 3),
#  ('cifras', 3),
#  ('acumulados', 3),
#  ('mapa', 3),
#  ('federativa', 3),
#  ('#covid19.😷…', 3),
#  ('técnico', 3),
#  ('coronavirus,', 3),
#  ('méxico:', 3),
#  ('año,', 3),
#  ('emergencia', 3),
#  ('if', 3),
#  ('@claudiashein', 3),
#  ('it', 3),
#  ('not', 3),
#  ('your', 3),
#  ('as', 3),
#  ('@tu_imss', 3),
#  ('cuarentena', 3),
#  ('amid', 3),
#  ('deseo', 3),
#  ('way', 3),
#  ('coronavirus.', 3),
#  ('they', 3),
#  ('7', 3),
#  ('@politicomx', 3),
#  ('an', 3),
#  ('fiesta', 3),
#  ('noticia', 3),
#  ('@lopezobrador_', 3),
#  ('"el', 3),
#  ('york', 3),
#  ('times', 3),
#  ('now', 3),
#  ('vivir', 3),
#  ('84', 3),
#  ('mañana', 3),
#  ('unam.', 3),
#  ('pinche', 3),
#  ('cdmx', 3),
#  ('imss', 3),
#  ('nadie,', 3),
#  ('jajaja', 3),
#  ('back', 3),
#  ('domingo', 3),
#  ('fallecidos', 3),
#  ('go', 3),
#  ('falleció', 3),
#  ('more', 3),
#  ('will', 3),
#  ('about', 3),
#  ('going', 3),
#  ('cubrebocas', 3),
#  ('&amp;', 3),
#  ('high', 2),
#  ('@cdcgov', 2),
#  ('diaria', 2),
#  ('vivienda', 2),
#  ('https://t.co/vnoqagnt5f…', 2),
#  ('federación', 2),
#  ('colegios', 2),
#  ('méxico,', 2),
#  ('#conferenciacoronavirus.', 2),
#  ('7,179', 2),
#  ('fallecidas', 2),
#  ('65,856', 2),
#  ('residencia', 2),
#  ('activos', 2),
#  ('🔸', 2),
#  ('fecha', 2),
#  ('curva', 2),
#  ('red', 2),
#  ('749', 2),
#  ('725', 2),
#  ('camas', 2),
#  ('⚡️', 2),
#  ('212', 2),
#  ('muestra', 2),
#  ('#hidalgo', 2),
#  ('qu…', 2),
#  ('pega', 2),
#  ('reporta', 2),
#  ('decesos', 2),
#  ('terrible', 2),
#  ('sáb', 2),
#  ('23/05/2020,', 2),
#  ('19:15', 2),
#  ('canceló', 2),
#  ('torneo', 2),
#  ('clausura', 2),
#  ('liga', 2),
#  ('mx', 2),
#  ('causa', 2),
#  ('regresé…', 2),
#  ('@faitelson_espn', 2),
#  ('rabia', 2),
#  ('#covid_19mexico', 2),
#  ('#covid19mx', 2),
#  ('#coronavirusmx…', 2),
#  ('casos"', 2),
#  ('good', 2),
#  ('gracias', 2),
#  ('want', 2),
#  ('@gobcdmx', 2),
#  ('me,', 2),
#  ('one', 2),
#  ('have', 2),
#  ('who', 2),
#  ('3', 2),
#  ('suma', 2),
#  ('190', 2),
#  ('@de', 2),
#  ('too', 2),
#  ('take', 2),
#  ('letalidad', 2),
#  ('nivel', 2),
#  ('how', 2),
#  ('many', 2),
#  ('americans', 2),
#  ('i…', 2),
#  ('went', 2),
#  ('golfing', 2),
#  ('today,', 2),
#  ('then', 2),
#  ('got', 2),
#  ('covid-19:', 2),
#  ('#coronaviruspandemic', 2),
#  ('@luisaalcalde', 2),
#  ('traer', 2),
#  ('24', 2),
#  ('3,329', 2),
#  ('#coronavirus,', 2),
#  ('cases', 2),
#  ('información', 2),
#  ('👇', 2),
#  ('ass', 2),
#  ('entrega', 2),
#  ('•', 2),
#  ('secretaría', 2),
#  ('#mexico', 2),
#  ('guadalajara', 2),
#  ('comunicado', 2),
#  ('diario:', 2),
#  ('➡️', 2),
#  ('https://t.co/cydxodgrhn', 2),
#  ('positivo', 2),
#  ('white', 2),
#  ('still', 2),
#  ('pri,', 2),
#  ('pan,', 2),
#  ('pt', 2),
#  ('pes', 2),
#  ('ven', 2),
#  ('incongruente', 2),
#  ('atender', 2),
#  ('eliminando', 2),
#  ('fonden', 2),
#  ('did', 2),
#  ('right', 2),
#  ('had', 2),
#  ('here', 2),
#  ('narrative', 2),
#  ('over', 2),
#  ('million', 2),
#  ('trump', 2),
#  ('datos', 2),
#  ('vean', 2),
#  ('@i_alaniis', 2),
#  ('cdmx,', 2),
#  ('cumpleaños', 2),
#  ('temática', 2),
#  ('@gopleader', 2),
#  ('give', 2),
#  ('iba', 2),
#  ('roma', 2),
#  ('@drjaimerivera', 2),
#  ('ve', 2),
#  ('homenaje', 2),
#  ('víctimas', 2),
#  ('mortales', 2),
#  ('his', 2),
#  ('triste', 2),
#  ('puesto', 2),
#  ('s…', 2),
#  ('tantos', 2),
#  ('vida,', 2),
#  ('ojos', 2),
#  ('vemos', 2),
#  ('torreón', 2),
#  ('sale', 2),
#  ('destacar', 2),
#  ('malo:', 2),
#  ('portadas', 2),
#  ('internet', 2),
#  ('columnas', 2),
#  ('https://t.co/ti39nhtpwv', 2),
#  ('https://t.co/hkpaymqabu', 2),
#  ('25', 2),
#  ('llevamos', 2),
#  ('alguien', 2),
#  ('medidas', 2),
#  ('covid-19;', 2),
#  ('detectan', 2),
#  ('entienden', 2),
#  ('🇲🇽', 2),
#  ('duda', 2),
#  ('pobre', 2),
#  ('lamentable', 2),
#  ('yucatan,', 2),
#  ('#quedateencasa', 2),
#  ('pasando', 2),
#  ('civil', 2),
#  ('@zoerobledo', 2),
#  ('quieren', 2),
#  ('hospital?', 2),
#  ('@luis_gj', 2),
#  ('5', 2),
#  ('54', 2),
#  ('6', 2),
#  ('hospitalizados', 2),
#  ('falta', 2),
#  ('me…', 2),
#  ('meses', 2),
#  ('masks', 2),
#  ('hospitals', 2),
#  ('portada', 2),
#  ('nombres', 2),
#  ('oms', 2),
#  ('oye', 2),
#  ('metieron', 2),
#  ('¿qué', 2),
#  ('pan', 2),
#  ('news', 2),
#  ('dumb', 2),
#  ('video', 2),
#  ('packed', 2),
#  ('ozark', 2),
#  ('lake', 2),
#  ('party', 2),
#  ('emerges', 2),
#  ('because', 2),
#  ('day', 2),
#  ('enfermos', 2),
#  ('tsunami', 2),
#  ('guarantee', 2),
#  ('gobierno', 2),
#  ('n…', 2),
#  ('1,000', 2),
#  ('hold', 2),
#  ('where', 2),
#  ('wuhan', 2),
#  ('#24mayo', 2),
#  ('mexicanos', 2),
#  ('advierte', 2),
#  ('"al', 2),
#  ('borde', 2),
#  ('guerra', 2),
#  ('fría"', 2),
#  ('ee.uu."', 2),
#  ('covid-19...', 2),
#  ('sanitización', 2),
#  ('(which', 2),
#  ('is)', 2),
#  ('things', 2),
#  ('us', 2),
#  ('abrazos', 2),
#  ('contingencia', 2),
#  ('being', 2),
#  ('#covid_19', 2),
#  ('vive', 2),
#  ('danza', 2),
#  ('bien,', 2),
#  ('4', 2),
#  ('expertos', 2),
#  ('privadas', 2),
#  ('prueba', 2),
#  ('octubre', 2),
#  ('influenza', 2),
#  ('corrupción', 2),
#  ('#stayhome', 2),
#  ('#coahuila', 2),
#  ('campeón', 2),
#  (':', 2),
#  ('peligroso', 2),
#  ('attack', 1),
#  ('rate', 1),
#  ('among', 1),
#  ('attendees', 1),
#  ('events', 1),
#  ('church', 1),
#  ('https://t.co/upixybipav', 1),
#  ('@lajornadaonline', 1),
#  ('@fonden_mx', 1),
#  ('@geofisicaunam', 1),
#  ('preocupan', 1),
#  ('estampitas', 1),
#  ('https://t.co/67amzrr8h8', 1),
#  ('#últimahora🔴|', 1),
#  ('comienza', 1),
#  ('prensa', 1),
#  ('#méxico.😷', 1),
#  ('sintoniza', 1),
#  ('vivo', 1),
#  ('📡👇…', 1),
#  ('https://t.co/pjbvwilepb', 1),
#  ('https://t.co/wcdiaprxx0', 1),
#  ('necesitan', 1),
#  ('correctivo.', 1),
#  ('suceda', 1),
#  ('casa,', 1),
#  ('instalaciones.', 1),
#  ('8', 1),
#  ('estu…', 1),
#  ('https://t.co/wnqzq0jwvt', 1),
#  ('62', 1),
#  ('jornada', 1),
#  ('sana', 1),
#  ('distancia', 1),
#  ('85', 1),
#  ('https://t.co/npwzzxmf3o', 1),
#  ('https://t.co/axbbwhhiqv', 1),
#  ('5,103,006', 1),
#  ('https://t.co/csf2hp6vvs', 1),
#  ('-&gt;14', 1),
#  ('253…', 1),
#  ('https://t.co/0ezbr5rqgk', 1),
#  ('elevan', 1),
#  ('covid19.', 1),
#  ('confirmad…', 1),
#  ('https://t.co/ydhv7ookhr', 1),
#  ('🔸65,856', 1),
#  ('🔸14,253', 1),
#  ('c…', 1),
#  ('https://t.co/txlzweakru', 1),
#  ('https://t.co/kihldxrblv', 1),
#  ('https://t.co/yfaycunmsz', 1),
#  ('tasa', 1),
#  ('incidencia', 1),
#  ('https://t.co/wrqhz8kelu', 1),
#  ('🆘', 1),
#  ('#fase3', 1),
#  ('🔴65,856', 1),
#  ('casos.', 1),
#  ('🔴7,179', 1),
#  ('muertes.', 1),
#  ('mantienen', 1),
#  ('3000', 1),
#  ('diario…', 1),
#  ('https://t.co/hhpf5n3ljj', 1),
#  ('registran', 1),
#  ('781', 1),
#  ('sospechosas', 1),
#  ('sumarían', 1),
#  ('fallec…', 1),
#  ('https://t.co/voth5jaq2y', 1),
#  ('acumuladas', 1),
#  ('defunción', 1),
#  ('federativa…', 1),
#  ('https://t.co/6byb08gibg', 1),
#  ('sospechosos', 1),
#  ('inicio', 1),
#  ('síntomas.', 1),
#  ('https://t.co/2t06jgfu5m', 1),
#  ('epidémica', 1),
#  ('incidentes', 1),
#  ('https://t.co/v0fmliuof9', 1),
#  ('irag,', 1),
#  ('notificantes', 1),
#  ('#covid19…', 1),
#  ('https://t.co/ade8tjpyao', 1),
#  ('chingas', 1),
#  ('puta', 1),
#  ('madre!!!', 1),
#  ('ahorita', 1),
#  ('mips', 1),
#  ('haciéndole', 1),
#  ('frente', 1),
#  ('corresponde,…', 1),
#  ('https://t.co/tl9lr9kaa5', 1),
#  ('wakanda', 1),
#  ('#sntesalud', 1),
#  ('⚕️', 1),
#  ('🚨', 1),
#  ('insomnio', 1),
#  ('💤🕙💤', 1),
#  ('#cuarentena', 1),
#  ('desorden', 1),
#  ('sueño', 1),
#  ('😴', 1),
#  ('pue…', 1),
#  ('https://t.co/42tl2al8k1', 1),
#  ('(', 1),
#  ('2020)', 1),
#  ('sumaron', 1),
#  ('3339', 1),
#  ('sumar', 1),
#  ('65,855', 1),
#  ('r…', 1),
#  ('https://t.co/rb2hhj6lih', 1),
#  ('resulta', 1),
#  ('exitosa', 1),
#  ('primeras', 1),
#  ('pruebas', 1),
#  ('https://t.co/w4y4abncfz', 1),
#  ('1186', 1),
#  ('resumen', 1),
#  ('https://t.co/n1tutrm5l7', 1),
#  ('atardecer', 1),
#  ('ayuda', 1),
#  ('reflexionar,', 1),
#  ('pensar', 1),
#  ('día.', 1),
#  ('signi…', 1),
#  ('https://t.co/ymbva003wn', 1),
#  ('alcanzó', 1),
#  ('pico', 1),
#  ('muertes,', 1),
#  ('sábado', 1),
#  ('3,329…', 1),
#  ('https://t.co/bkcxrnqczv', 1),
#  ('@hlgatell', 1),
#  ('dr', 1),
#  ('referente', 1),
#  ('enfermedades', 1),
#  ('acompañan', 1),
#  ('pregunta,', 1),
#  ('espero', 1),
#  ('https://t.co/e9pypuaiuz', 1),
#  ('creerse', 1),
#  ('culo', 1),
#  ('pendeja', 1),
#  ('irag', 1),
#  ('(infección', 1),
#  ('respiratoria', 1),
#  ('aguda', 1),
#  ('grave),', 1),
#  ('notificantes,', 1),
#  ('(97%)', 1),
#  ('presentaron', 1),
#  ('repor…', 1),
#  ('https://t.co/s5x4phgye8', 1),
#  ('2020,', 1),
#  ('(3,329', 1),
#  ('#coronavirus),', 1),
#  ('desc…', 1),
#  ('https://t.co/0hzuyduo0s', 1),
#  ('periódico', 1),
#  ('2,960', 1),
#  ('1,854', 1),
#  ('cdmx.', 1),
#  ('https://t.co/cabar1l4fq', 1),
#  ('acostumbramos', 1),
#  ('números.', 1),
#  ('100,', 1),
#  ('000', 1),
#  ('eu.', 1),
#  ('100,…', 1),
#  ('https://t.co/worbinaebt', 1),
#  ('@dafneconefe', 1),
#  ('inútiles', 1),
#  ('pagan', 1),
#  ('antivirus', 1),
#  ('dominios.', 1),
#  ('@nytimes', 1),
#  ('burguesía', 1),
#  ('internacional', 1),
#  ('local', 1),
#  ('se…', 1),
#  ('https://t.co/sy7ii9ns9f', 1),
#  ('insiste', 1),
#  ('multimedios', 1),
#  ('"paola"', 1),
#  ('insumos', 1),
#  ('#multimediosesgolpista', 1),
#  ('https://t.co/jam8tts0gz', 1),
#  ('https://t.co/fshjszc2am', 1),
#  ('dios', 1),
#  ('way,', 1),
#  ('brady', 1),
#  ('patriotas,', 1),
#  ('adiós', 1),
#  ('guede', 1),
#  ('https://t.co/rwh3avedx7', 1),
#  ('@reforma', 1),
#  ('sirve', 1),
#  ('material', 1),
#  ('https://t.co/5jaljeufsv', 1),
#  ('@jiimmyvera', 1),
#  ('especulaciones.', 1),
#  ('esposa', 1),
#  ('susto', 1),
#  ('alboroto', 1),
#  ('gresca', 1),
#  ('hubo.…', 1),
#  ('https://t.co/io1pcxi3bt', 1),
#  ('fútbol', 1),
#  ('para,', 1),
#  ('puto', 1),
#  ('🥰', 1),
#  ('#seacabolachela', 1),
#  ('#covid_19mx', 1),
#  ('#conlafamiliano', 1),
#  ('#covid19mexico', 1),
#  ('https://t.co/s03kzx7ifl', 1),
#  ('https://t.co/tiqcta4v6b', 1),
#  ('@braveheart_usa', 1),
#  ('@txjean2014', 1),
#  ('empty', 1),
#  ('hospitals.', 1),
#  ('false', 1),
#  ('data.', 1),
#  ('criminal', 1),
#  ('corruption.', 1),
#  ('another', 1),
#  ('fake', 1),
#  ('hoax.', 1),
#  ('ars', 1),
#  ('technica:', 1),
#  ('results', 1),
#  ('remdesivir', 1),
#  ('trial', 1),
#  ('out,', 1),
#  ('it’s', 1),
#  ('news.', 1),
#  ('https://t.co/5nu4jttzsa', 1),
#  ('@googlenews', 1),
#  ('objetivo!', 1),
#  ('#hospitalgeneralbalbuena', 1),
#  ('https://t.co/jcgu5gxdxh', 1),
#  ('disponibilidad', 1),
#  ('afrontar', 1),
#  ('https://t.co/wmsxgcwuft', 1),
#  ('@scottgottliebmd', 1),
#  ('@wsj', 1),
#  ('viable', 1),
#  ('solution', 1),
#  ('read', 1),
#  ('tweets', 1),
#  ('pertaining', 1),
#  ('copper', 1),
#  ('thank', 1),
#  ('you!', 1),
#  ('does', 1),
#  ('nobody', 1),
#  ('seem', 1),
#  ('middle', 1),
#  ('side,', 1),
#  ('wanting', 1),
#  ('https://t.co/sgqvthuyfw', 1),
#  ('finaliza', 1),
#  ('base', 1),
#  ('#coronavirus.😷', 1),
#  ('▶️mañana', 1),
#  ('7pm', 1),
#  ('📡', 1),
#  ('https://t.co/zwaeewnmyo', 1),
#  ('día;', 1),
#  ('https://t.co/0dttybkrbv', 1),
#  ('po…', 1),
#  ('https://t.co/0qllxqd4re', 1),
#  ('@jonahdispatch', 1),
#  ('explanation', 1),
#  ('simplistic.', 1),
#  ('started', 1),
#  ('should', 1),
#  ('seriously', 1),
#  ('turned', 1),
#  ('into…', 1),
#  ('https://t.co/n7im9hfdwf', 1),
#  ('@c5_cdmx', 1),
#  ('#especiales', 1),
#  ('#meganoticias', 1),
#  ('panorama', 1),
#  ('basado', 1),
#  ('fuente', 1),
#  ('j…', 1),
#  ('https://t.co/foizctqvef', 1),
#  ('10.90', 1),
#  ('ciento.', 1),
#  ('mundial', 1),
#  ('6.5', 1),
#  ('ciento…', 1),
#  ('https://t.co/ipo4y38xyn', 1),
#  ('@diccionarioalad', 1),
#  ('vote', 1),
#  ('plasma,', 1),
#  ('ntro', 1),
#  ('chino', 1),
#  ('eua.', 1),
#  ('relaciones', 1),
#  ('wonder', 1),
#  ('due', 1),
#  ('response', 1),
#  ('think', 1),
#  ('great.', 1),
#  ('https://t.co/qb4zgujhtd', 1),
#  ('yankees', 1),
#  ('playing', 1),
#  ('hardball', 1),
#  ('ticket', 1),
#  ('refunds', 1),
#  ('fans', 1),
#  ('say', 1),
#  ('https://t.co/kdkncgugrs', 1),
#  ('@nypostsports', 1),
#  ('president', 1),
#  ('busy', 1),
#  ('ate', 1),
#  ('dinner,', 1),
#  ('https://t.co/fwkxwlz2xb', 1),
#  ('@lauramanzo', 1),
#  ('ea', 1),
#  ('https://t.co/dxwu1toznm', 1),
#  ('hola', 1),
#  ('noches', 1),
#  ('encuentren', 1),
#  ('bien.', 1),
#  ('solicito', 1),
#  ('donadores', 1),
#  ('padre', 1),
#  ('hospitalizado', 1),
#  ('el…', 1),
#  ('https://t.co/sqjnyu2wqs', 1),
#  ('@who', 1),
#  ('#infecciónendémica', 1),
#  ('https://t.co/8s2c55fpjy', 1),
#  ('@clouthiermanuel', 1),
#  ('greñas.', 1),
#  ('@robsabatino', 1),
#  ('@sheriffchitwood', 1),
#  ('here’s', 1),
#  ('better', 1),
#  ('phrase', 1),
#  ('said:', 1),
#  ('until', 1),
#  ('seri…', 1),
#  ('https://t.co/wrycp6df52', 1),
#  ('registrado', 1),
#  ('equivale', 1),
#  ('in…', 1),
#  ('https://t.co/ycyochau5c', 1),
#  ('big', 1),
#  ('bend', 1),
#  ('by', 1),
#  ('county,', 1),
#  ('courtesy', 1),
#  ('@tdonline', 1),
#  ('https://t.co/dgxfehd10t', 1),
#  ('1,192', 1),
#  ('https://t.co/wie4uqtvy7', 1),
#  ('#coronavirusenelmundo', 1),
#  ('https://t.co/fbwxdy1cuj', 1),
#  ('nearly', 1),
#  ('bum', 1),
#  ('today', 1),
#  ('https://t.co/thk8ln6jrm', 1),
#  ('@2ciaandy', 1),
#  ('corto', 1),
#  ('tiempo.', 1),
#  ('vino', 1),
#  ('atrasar', 1),
#  ('lo…', 1),
#  ('https://t.co/ujk2dfza7b', 1),
#  ('termine', 1),
#  ('mandato.', 1),
#  ('@wfla', 1),
#  ('them!', 1),
#  ("aren't", 1),
#  ('risk', 1),
#  ('group', 1),
#  ('anyhow,', 1),
#  ('transmit', 1),
#  ('less', 1),
#  ('ventilación', 1),
#  ('mecánica', 1),
#  ('🔴', 1),
#  ('intubación', 1),
#  ('dolorosa', 1),
#  ('consiste', 1),
#  ('inserta', 1),
#  ('tubo', 1),
#  ('boca…', 1),
#  ('https://t.co/yltpma16mb', 1),
#  ('@tiendaunam', 1),
#  ('¿tendrán', 1),
#  ('planes', 1),
#  ('domicio?', 1),
#  ('@faraon_gabriel', 1),
#  ('@elitenetflix', 1),
#  ('culpa,', 1),
#  ('#unamenpaz', 1),
#  ('grupos', 1),
#  ('políticos', 1),
#  ('#últimahora', 1),
#  ('😷|méxico', 1),
#  ('rebasa', 1),
#  ('reportó', 1),
#  ('defuncion…', 1),
#  ('https://t.co/28d75lvnap', 1),
#  ('?', 1),
#  ('méxico!!', 1),
#  ('🤷🏽\u200d♂️', 1),
#  ('....', 1),
#  ('#instagood', 1),
#  ('#lgbtq🌈', 1),
#  ('#photograper', 1),
#  ('#insta', 1),
#  ('#hottoys', 1),
#  ('#gay', 1),
#  ('#crown', 1),
#  ('#instaphoto', 1),
#  ('#coronavirusitaly…', 1),
#  ('https://t.co/choeatfth9', 1),
#  ('@alvaro_delgado', 1),
#  ('@enriquealfaror', 1),
#  ('viene', 1),
#  ('área', 1),
#  ('metropolitana', 1),
#  ('pasado…', 1),
#  ('https://t.co/e18y7243vf', 1),
#  ('https://t.co/hssj5b2bbe', 1),
#  ('https://t.co/ofxfg7sfto', 1),
#  ('@satanic_plastic', 1),
#  ('evitar', 1),
#  ('sentir', 1),
#  ('sabiendo', 1),
#  ('muriendo', 1),
#  ('hospitales;', 1),
#  ('por…', 1),
#  ('https://t.co/79sg6et8wu', 1),
#  ('@sophieyunes', 1),
#  ('positiva', 1),
#  ('coronavirus-19.', 1),
#  ('seguro', 1),
#  ('reservando', 1),
#  ('parami', 1),
#  ('some', 1),
#  ('considering', 1),
#  ('hoax.....', 1),
#  ('also', 1),
#  ('them:', 1),
#  ('https://t.co/tnui2jptfz', 1),
#  ('@santoyguerrero', 1),
#  ('@jzermenoi', 1),
#  ('%', 1),
#  ('@municipiotrc', 1),
#  ('3.6%', 1),
#  ('es…', 1),
#  ('https://t.co/yhstk0seql', 1),
#  ('mascara', 1),
#  ('culera', 1),
#  ('llena', 1),
#  ('pinches', 1),
#  ('oyos!', 1),
#  ('mamar!!', 1),
#  ('🤣😂👍', 1),
#  ('https://t.co/dnnieytby0', 1),
#  ('suman', 1),
#  ('179', 1),
#  ('afecta', 1),
#  ('https://t.co/rx8okkwcdb', 1),
#  ('https://t.co/i7xx4g6zvj', 1),
#  ('ocupo', 1),
#  ('ya!!', 1),
#  ('#quierounamo', 1),
#  ('ashh', 1),
#  ('pidan', 1),
#  ('educación', 1),
#  ('estudiaron', 1),
#  ('poli,', 1),
#  ('nacos.', 1),
#  ('calificando', 1),
#  ('distancia,', 1),
#  ('palomitas', 1),
#  ('taches', 1),
#  ('siente', 1),
#  ('papel,', 1),
#  ('jijiji', 1),
#  ('ay…', 1),
#  ('https://t.co/r3fbqvnjfl', 1),
#  ('unfortunately', 1),
#  ('lessons.', 1),
#  ('also,', 1),
#  ('speaking', 1),
#  ('hisstory,', 1),
#  ('outdoor', 1),
#  ('bost…', 1),
#  ('https://t.co/qapjohcbdr', 1),
#  ('domicilio', 1),
#  ('particular', 1),
#  ('ángeles,', 1),
#  ('policia', 1),
#  ('@sspmqueretaro', 1),
#  ('historia', 1),
#  ('recordado:', 1),
#  ('fiestas', 1),
#  ('clase', 1),
#  ('privilegiada', 1),
#  ('pese…', 1),
#  ('https://t.co/8cmaad4vnq', 1),
#  ('gon', 1),
#  ('whether', 1),
#  ('you’re', 1),
#  ('inside', 1),
#  ('out.', 1),
#  ('1.6', 1),
#  ('almost', 1),
#  ('dickrider', 1),
#  ('again', 1),
#  ('balls', 1),
#  ('deep', 1),
#  ('praising…', 1),
#  ('https://t.co/ptiis2wjsx', 1),
#  ('🤷🏾\u200d♂️🤷🏾\u200d♂️', 1),
#  ('mom…', 1),
#  ('https://t.co/kfrcotl8rs', 1),
#  ('etc,', 1),
#  ('basta', 1),
#  ('voto,', 1),
#  ('sirvió', 1),
#  ('señor,', 1),
#  ('cosa', 1),
#  ('(covid-19)', 1),
#  ('cambios', 1),
#  ('favor…', 1),
#  ('https://t.co/crtxbeqgdm', 1),
#  ('vergüenza', 1),
#  ('autoridades', 1),
#  ('poniendo', 1),
#  ('jaque', 1),
#  ('escuela', 1),
#  ('@tvunam', 1),
#  ('salu2', 1),
#  ('#cinemateca', 1),
#  ('periodistas', 1),
#  ('neoberalismo', 1),
#  ('consumismo', 1),
#  ('falso', 1),
#  ('illuminatti.', 1),
#  ('llegado', 1),
#  ('festejando', 1),
#  ('harry', 1),
#  ('potter', 1),
#  ('@catedrabergman', 1),
#  ('@festivalhuesca', 1),
#  ('@culturaunam', 1),
#  ('@filmotecaunam', 1),
#  ('@teatrounam', 1),
#  ('@ficunam', 1),
#  ('@festivalfitu', 1),
#  ('@radiounam…', 1),
#  ('https://t.co/jjbeumc3lf', 1),
#  ('@villanito', 1),
#  ('@queretano1950', 1),
#  ('insisten', 1),
#  ('existe"', 1),
#  (',', 1),
#  ('conocen', 1),
#  ('contagiado...', 1),
#  ('fines', 1),
#  ('sema…', 1),
#  ('https://t.co/tzqe83lviw', 1),
#  ('break', 1),
#  ('reas', 1),
#  ('science', 1),
#  ('journals', 1),
#  ('-who', 1),
#  ('let', 1),
#  ('administration', 1),
#  ('know', 1),
#  ('last', 1),
#  ('week', 1),
#  ('december🇺🇸🥊', 1),
#  ('desigualdad', 1),
#  ('🧐', 1),
#  ('existido', 1),
#  ('secundaria', 1),
#  ('odiabaaa', 1),
#  ('maestros', 1),
#  ('prepa', 1),
#  ('🥺🥺', 1),
#  ('https://t.co/zc8jgqn5ej', 1),
#  ('rola', 1),
#  ('activa', 1),
#  ('hornyvirus', 1),
#  ('https://t.co/ked0jcamzk', 1),
#  ('@lacoloniajuarez', 1),
#  ('@vecinossurroma', 1),
#  ('@aristeguionline', 1),
#  ('colonia', 1),
#  ('ángeles', 1),
#  ('jejeje', 1),
#  ('xoco,', 1),
#  ('veas', 1),
#  ('eficiencia', 1),
#  ('eficacia', 1),
#  ('https://t.co/kjxle1k24n', 1),
#  ('covid-19"', 1),
#  ('https://t.co/zd07cf1juc', 1),
#  ...]

# %%
obtenerTendencias(muestra)
# Out:
# [('covid-19', 764),
#  ('coronavirus', 448),
#  ('casos', 318),
#  ('#coronavirus', 274),
#  ('hospital', 253),
#  ('virus', 247),
#  ('hospitales', 186),
#  ('covid-19,', 154),
#  ('méxico', 147),
#  ('#noqueremosmásmentiras', 118),
#  ('@vtvcanal8:', 99),
#  ('#covid19', 95),
#  ('contagios', 91),
#  ('venezuela', 84),
#  ('personas', 83),
#  ('salud', 83),
#  ('país', 82),
#  ('pruebas', 82),
#  ('mil', 79),
#  ('gobierno', 72),
#  ('covid-19.', 71),
#  ('pacientes', 65),
#  ('pandemia', 64),
#  ('24', 63),
#  ('.', 62),
#  ('this', 60),
#  ('@mippcivzla:', 57),
#  ('mundo', 56),
#  ('#envivo', 55),
#  ('for', 55),
#  ('coronavirus.', 55),
#  ('📹', 55),
#  ('muertes', 53),
#  ('#actualización⭕|', 53),
#  ('🦠', 52),
#  ('contagio', 51),
#  ('that', 50),
#  ('coronavirus,', 49),
#  ('atender', 49),
#  ('enfermos', 49),
#  ('mayo', 45),
#  ('muertos', 44),
#  ('on', 43),
#  ('vía', 42),
#  ('confirmados', 42),
#  ('#envideo', 42),
#  ('virus,', 40),
#  ('covid-19:', 40),
#  ('you', 40),
#  ('atención', 40),
#  ('contagiados', 39),
#  ('@jtolentinoroman:', 39),
#  ('have', 38),
#  ('personal', 38),
#  ('positivos', 38),
#  ('¿porqué', 38),
#  ('2020', 37),
#  ('@unam_mx', 36),
#  ('#covid-19', 36),
#  ('d…', 35),
#  ('¿cómo', 35),
#  ('new', 35),
#  ('gente', 34),
#  ('@lopezobrador_', 34),
#  ('continúa', 34),
#  ('brote', 34),
#  ('@nicolasmaduro:', 34),
#  ('médicos', 33),
#  ('with', 33),
#  ('as', 33),
#  ('jornada', 33),
#  ('#sntesalud', 33),
#  ('cifra', 32),
#  ('⚕️', 32),
#  ('unam', 32),
#  ('cifras', 31),
#  ('tiempos', 31),
#  ('20', 31),
#  ('🗣️', 31),
#  ('✍️🇻🇪', 31),
#  ('maduro', 31),
#  ('vida', 31),
#  ('be', 30),
#  ('from', 30),
#  ('at', 30),
#  ('acciones', 30),
#  ('1000', 30),
#  ('emergencia', 30),
#  ('tant…', 30),
#  ('it', 29),
#  ('trump', 29),
#  ('de…', 29),
#  ('mexico', 29),
#  ('e…', 29),
#  ('número', 29),
#  ('camas', 29),
#  ('we', 28),
#  ('3', 28),
#  ('sector', 28),
#  ('contención', 28),
#  ('control', 28),
#  ('san', 28),
#  ('calderón', 28),
#  ('6', 28),
#  ('covid', 27),
#  ('are', 27),
#  ('...', 27),
#  ('corona', 27),
#  ('detectado', 27),
#  ('h…', 27),
#  ('situación', 26),
#  ('cdmx', 26),
#  ('gracias', 26),
#  ('positivo', 26),
#  ('frente', 26),
#  ('10', 26),
#  ('!', 26),
#  ('felipe', 26),
#  ('21', 26),
#  ('about', 25),
#  ('virus.', 25),
#  ('#solidaridadydisciplina', 25),
#  ('reforzar', 25),
#  ('enfermeras', 25),
#  ('5', 25),
#  ('https://t.c…', 25),
#  ('#méxico', 25),
#  ('curva', 25),
#  ('8', 24),
#  ('not', 24),
#  ('t…', 24),
#  ('brasil', 24),
#  ('nacional', 24),
#  ('coronavirus:', 23),
#  ('🔴', 23),
#  ('if', 23),
#  ('cases', 23),
#  ('oms', 23),
#  ('🚨', 23),
#  ('pasantes', 23),
#  ('cuarentena', 22),
#  ('#coronavirus,', 22),
#  ('medidas', 22),
#  ('gobernador', 22),
#  ('crisis', 22),
#  ('covid-19?', 22),
#  ('países', 22),
#  ('@claudiashein:', 22),
#  ('i…', 22),
#  ('familia', 21),
#  ('how', 21),
#  ('china', 21),
#  ('they', 21),
#  ('#covid_19', 21),
#  ('hospitales.', 21),
#  ('vacuna', 21),
#  ('pdte.', 21),
#  ('servicio', 21),
#  ('delcy', 21),
#  ('@unam_mx:', 21),
#  ('23', 21),
#  ('defunciones', 20),
#  ('was', 20),
#  ('diario', 20),
#  ('can', 20),
#  ('redes', 20),
#  ('been', 20),
#  ('años', 20),
#  ('an', 20),
#  ('informa', 20),
#  ('imss', 20),
#  ('#fase3', 20),
#  ('so', 20),
#  ('#87punto3', 20),
#  ('supera', 20),
#  ('equipo', 19),
#  ('all', 19),
#  ('just', 19),
#  ('seguir', 19),
#  ('people', 19),
#  ('spread', 19),
#  ('a…', 19),
#  ('11', 19),
#  ('evitar', 19),
#  ('dejado', 19),
#  ('|…', 19),
#  ('hospitales;', 19),
#  ('my', 18),
#  ('do', 18),
#  ('sistema', 18),
#  ('zona', 18),
#  (',', 18),
#  ('médico', 18),
#  ('semana', 18),
#  ('@ntn24ve:', 18),
#  ('presidente', 18),
#  ('#20may', 18),
#  ('@la_patilla:', 18),
#  ('alta', 18),
#  ('¿dónde', 18),
#  ('méxico,', 18),
#  ('conferencia', 18),
#  ('ocde', 18),
#  ('miles', 18),
#  ('alto', 17),
#  ('hospitals', 17),
#  ('by', 17),
#  ('what', 17),
#  ('📹|', 17),
#  ('#…', 17),
#  ('[#ahora]', 17),
#  ('alguien', 17),
#  ('@drdenagrayson:', 17),
#  ('mexicanos', 17),
#  ('@sinlineamx:', 17),
#  ('escapa...', 17),
#  ('decía', 17),
#  ('están?', 17),
#  ('🤷\u200d♀️', 17),
#  ('http…', 17),
#  ('santos', 17),
#  ('y…', 17),
#  ('#coronavirus…', 17),
#  ('⚠️', 17),
#  ('@epigmenioibarra:', 17),
#  ('miente!no', 17),
#  ('construyo', 17),
#  ('panteón,una', 17),
#  ('gigantesca', 17),
#  ('fosa', 17),
#  ('clandestina.', 17),
#  ('crímenes', 17),
#  ('lesa', 17),
#  ('huma…', 17),
#  ('#quedateencasa', 16),
#  ('your', 16),
#  ('reporte', 16),
#  ('pandemic', 16),
#  ('director', 16),
#  ('more', 16),
#  ('than', 16),
#  ('síntomas', 16),
#  ('tipo', 16),
#  ('transmisión', 16),
#  ('incremento', 16),
#  ('hospitalización.', 16),
#  ('federal', 16),
#  ('caso', 16),
#  ('hace,', 16),
#  ('falta', 15),
#  ('"covid-19:', 15),
#  ('propagación', 15),
#  ('#quédateencasa', 15),
#  ('entrega', 15),
#  ('2', 15),
#  ('hospitalaria', 15),
#  ('even', 15),
#  ('reporta', 15),
#  ('¡𝐄𝐒', 15),
#  ('𝐂𝐎𝐍𝐓𝐈𝐆𝐎', 15),
#  ('had', 15),
#  ('registra', 15),
#  ('necesario', 15),
#  ('el…', 15),
#  ('josé', 15),
#  ('now', 15),
#  ('via', 15),
#  ('anunciamos', 15),
#  ('sanitaria.', 15),
#  ('contin…', 15),
#  ('estudio', 15),
#  ('luis', 15),
#  ('#uhcoronavirus', 15),
#  ('información', 15),
#  ('#covid19.😷', 15),
#  ('sobrevivir', 15),
#  ('times', 15),
#  ('60', 15),
#  ('prueba', 14),
#  ('#venezuela', 14),
#  ('que…', 14),
#  ('cubrebocas', 14),
#  ('4', 14),
#  ('out', 14),
#  ('meses', 14),
#  ('reportan', 14),
#  ('75', 14),
#  ('nicolás', 14),
#  ('hospitalizados', 14),
#  ('persona', 14),
#  ('m…', 14),
#  ('may', 14),
#  ('niños', 14),
#  ('reportaron', 14),
#  ('jugadores', 14),
#  ('hospital…', 14),
#  ('social', 14),
#  ('#coronavirus.😷', 14),
#  ('po…', 14),
#  ('@macuilxchitl:', 14),
#  ('rodríguez:', 14),
#  ('por…', 13),
#  ('pinche', 13),
#  ('amlo', 13),
#  ('murió', 13),
#  ('importante', 13),
#  ('comentario', 13),
#  ('datos', 13),
#  ('why', 13),
#  ('will', 13),
#  ('insumos', 13),
#  ('onu', 13),
#  ('sanciones', 13),
#  ('habitaciones', 13),
#  ('@johncardillo:', 13),
#  ('colombia', 13),
#  ('miércoles', 13),
#  ('universitario', 13),
#  ('😷', 13),
#  ('seguridad', 13),
#  ('siguen', 13),
#  ('pueblo', 13),
#  ('apoyo', 13),
#  ('hospital,', 13),
#  ('#cuarentena', 13),
#  ('llega', 13),
#  ('ciudad', 13),
#  ('l…', 13),
#  ('compañeros', 13),
#  ('resultados', 13),
#  ('suman', 13),
#  ('entidad', 13),
#  ('interior', 13),
#  ('#atención', 13),
#  ('🗣️|', 13),
#  ('convirtió', 13),
#  ('347.398', 13),
#  ('#vencere…', 13),
#  ('covid-19…', 12),
#  ('@gobcdmx', 12),
#  ('vive', 12),
#  ('when', 12),
#  ('semáforo', 12),
#  ('casa', 12),
#  ('get', 12),
#  ('1', 12),
#  ('s…', 12),
#  ('forma', 12),
#  ('público', 12),
#  ('&amp;', 12),
#  ('dr.', 12),
#  ('ee.uu.', 12),
#  ('https://t.…', 12),
#  ('secretario', 12),
#  ('eleva', 12),
#  ('dotan', 12),
#  ('acondicionan', 12),
#  ('ambulatorio', 12),
#  ('ivss', 12),
#  ('chivacoa', 12),
#  ('enfermedades', 12),
#  ('@albertoravell:', 12),
#  ('señor', 12),
#  ('after', 12),
#  ('response', 12),
#  ('fase', 12),
#  ('comparten', 12),
#  ('@ultimahsv:', 12),
#  ('nivel', 12),
#  ('debemos', 12),
#  ('manteniendo', 12),
#  ('actualización', 12),
#  ('disponibles', 12),
#  ('decesos', 12),
#  ('llaman', 12),
#  ('evidencia', 12),
#  ('cubrir', 12),
#  ('#hospitaluniversitario', 12),
#  ('@joluisgarcia:', 12),
#  ('hu,', 12),
#  ('350', 12),
#  ('acudirán', 12),
#  ('#venceremosalcovid1…', 12),
#  ('p…', 11),
#  ('many', 11),
#  ('#mexico', 11),
#  ('but', 11),
#  ('contingencia', 11),
#  ('who', 11),
#  ('víctimas', 11),
#  ('wuhan', 11),
#  ('enfermera', 11),
#  ('millones', 11),
#  ('c…', 11),
#  ('@nicolasmaduro,', 11),
#  ('todos…', 11),
#  ('sin…', 11),
#  ('campaña', 11),
#  ('@reporteya:', 11),
#  ('foto', 11),
#  ('mayo,', 11),
#  ('covid-19;', 11),
#  ('our', 11),
#  ('@carlosloret:', 11),
#  ('china.', 11),
#  ('protección', 11),
#  ('22', 11),
#  ('río', 11),
#  ('or', 11),
#  ('exigen', 11),
#  ('se…', 11),
#  ('régimen', 11),
#  ('muerte', 11),
#  ('@beatrizgmuller:', 11),
#  ('#susanadistancia.', 11),
#  ('#quédatee…', 11),
#  ('secretaría', 11),
#  ('did', 11),
#  ('activos', 11),
#  ('técnico', 11),
#  ('liga', 11),
#  ('test', 11),
#  ('alerta', 11),
#  ('#noqueremosmasmentiras', 11),
#  ('detectar', 11),
#  ('pobres', 11),
#  ('busca', 11),
#  ('importados', 11),
#  ('15', 11),
#  ('masiva', 11),
#  ('cancela', 11),
#  ('hu', 11),
#  ('@luisbeza:', 11),
#  ('tu…', 11),
#  ('llegada', 11),
#  ('#23may', 11),
#  ('hospitales,', 10),
#  ('day', 10),
#  ('go', 10),
#  ('back', 10),
#  ('anuncia', 10),
#  ('#unam', 10),
#  ('riesgo', 10),
#  ('7', 10),
#  ('ven', 10),
#  ('#covid19,', 10),
#  ('en…', 10),
#  ('fallecidos', 10),
#  ('know', 10),
#  ('sanitaria', 10),
#  ('condena', 10),
#  ('https…', 10),
#  ('#so…', 10),
#  ('824', 10),
#  ('@hildarubi:', 10),
#  ('𝑺𝒂𝒃𝒊́𝒂𝒔', 10),
#  ('𝒒𝒖𝒆', 10),
#  ('causar', 10),
#  ('formas', 10),
#  ('leves', 10),
#  ('manuel', 10),
#  ('olivares', 10),
#  ('centro', 10),
#  ('denunciar', 10),
#  ('construyó', 10),
#  ('fallecieron', 10),
#  ('patients', 10),
#  ('#hidalgo', 10),
#  ('12', 10),
#  ('registran', 10),
#  ('ecologista', 10),
#  ('apuesta', 10),
#  ('iba', 10),
#  ('#noticias', 10),
#  ('mujer', 10),
#  ('querétaro', 10),
#  ('@sopitas:', 10),
#  ('@enriquealfaror', 10),
#  ('mañana', 10),
#  ('causa', 10),
#  ('take', 10),
#  ('@msicg:', 10),
#  ('msicg', 10),
#  ('sindicato', 10),
#  ('emetra', 10),
#  ('@minsaludguate', 10),
#  ('realizadas', 10),
#  ('pmt.…', 10),
#  ('@clubsantos', 10),
#  ('acumulados', 10),
#  ('veracruz', 10),
#  ('científica', 10),
#  ('#video', 10),
#  ('enfermeros', 10),
#  ('@bacalaomandinga:', 10),
#  ('arrechos', 10),
#  ('importamos', 10),
#  ('"connaciona…', 10),
#  ('vpdta.', 10),
#  ('@drodriven2', 10),
#  ('up', 9),
#  ('cura', 9),
#  ('base', 9),
#  ('enfermedad', 9),
#  ('media', 9),
#  ('🇲🇽', 9),
#  ('?', 9),
#  ('miedo', 9),
#  ('300', 9),
#  ('would', 9),
#  ('q…', 9),
#  ('amid', 9),
#  ('york', 9),
#  ('@redradiove:', 9),
#  ('#últimahora:', 9),
#  ('¿ya', 9),
#  ('pregunto:', 9),
#  ('contagiando', 9),
#  ('duda', 9),
#  ('pro…', 9),
#  ('https://t.co/…', 9),
#  ('96%', 9),
#  ('vega', 9),
#  ('mascarillas', 9),
#  ('#pandemiadelcoronavirus', 9),
#  ('aumento', 9),
#  ('reported', 9),
#  ('last', 9),
#  ('any', 9),
#  ('his', 9),
#  ('@m_zamarripa:', 9),
#  ('#urgente!', 9),
#  ('desaparición', 9),
#  ('–', 9),
#  ('confirma', 9),
#  ('100', 9),
#  ('laguna', 9),
#  ('¿te', 9),
#  ('interesa', 9),
#  ('team', 9),
#  ('co…', 9),
#  ('juan', 9),
#  ('@ssalud_mx', 9),
#  ('mapa', 9),
#  ('federativa', 9),
#  ('#covid19.😷…', 9),
#  ('⚡️', 9),
#  ('universidad', 9),
#  ('cuarto', 9),
#  ('torreón', 9),
#  ('#covidー19', 9),
#  ('@alfredodelmazo', 9),
#  ('resultar', 9),
#  ('@realdonaldtrump', 9),
#  ('tantos…', 9),
#  ('mascarilla', 9),
#  ('leaves', 9),
#  ('veo', 9),
#  ('cdc:', 9),
#  ('ny', 9),
#  ('ojalá', 8),
#  ('vida.', 8),
#  ('@el_universal_mx', 8),
#  ('see', 8),
#  ('hospital.', 8),
#  ('time', 8),
#  ('post', 8),
#  ('amigos', 8),
#  ('there', 8),
#  ('their', 8),
#  ('residentes', 8),
#  ('salud,', 8),
#  ('like', 8),
#  ('@hlgatell', 8),
#  ('registró', 8),
#  ('récord', 8),
#  ('@luunamx', 8),
#  ('combatir', 8),
#  ('https://t.co…', 8),
#  ('80%', 8),
#  ('respiratorio,', 8),
#  ('sumemos', 8),
#  ('preventiva', 8),
#  ('común', 8),
#  ('yucatán', 8),
#  ('🧬', 8),
#  ('recuperados', 8),
#  ('autoridades', 8),
#  ('during', 8),
#  ('horas,', 8),
#  ('no.', 8),
#  ('one', 8),
#  ('covid19,', 8),
#  ('población', 8),
#  ('"el', 8),
#  ('atendidos', 8),
#  ('consultar', 8),
#  ('encuestas', 8),
#  ('@elfinanciero_mx?', 8),
#  ('links', 8),
#  ('plan', 8),
#  ('recibir', 8),
#  ('face', 8),
#  ('#florida', 8),
#  ('resultado', 8),
#  ('vaccine', 8),
#  ('quieren', 8),
#  ('#coronavirus.', 8),
#  ('fallecimientos', 8),
#  ('#covid-19,', 8),
#  ('@aristeguionline:', 8),
#  ('falleció', 8),
#  ('puedes', 8),
#  ('grande', 8),
#  ('¿qué', 8),
#  ('fecha', 8),
#  ('real', 8),
#  ('qu…', 8),
#  ('realidad', 8),
#  ('trabajadores', 8),
#  ('going', 8),
#  ('virus…', 8),
#  ('sueño', 8),
#  ('😴', 8),
#  ('news', 8),
#  ('“méxico', 8),
#  ('día”:', 8),
#  ('economist.', 8),
#  ('con…', 8),
#  ('good', 8),
#  ('❎', 8),
#  ('portada', 8),
#  ('colorado.', 8),
#  ('counting', 8),
#  ('error', 8),
#  ('epidemiologists', 8),
#  ('‘really', 8),
#  ('baffled’', 8),
#  ('reluctantly', 8),
#  ('@cmonterooficial:', 8),
#  ('seguro', 7),
#  ('19', 7),
#  ('azul', 7),
#  ('cuidado', 7),
#  ('16', 7),
#  ('want', 7),
#  ('state', 7),
#  ('salir', 7),
#  ('another', 7),
#  ('right', 7),
#  ('covid19', 7),
#  ('regreso', 7),
#  ('seguimiento', 7),
#  ('no…', 7),
#  ('maestros', 7),
#  ('fallecido', 7),
#  ('tierra', 7),
#  ('humanos', 7),
#  ('n…', 7),
#  ('ahorita', 7),
#  ('also', 7),
#  ('being', 7),
#  ('padre', 7),
#  ('nombre', 7),
#  ('mujeres', 7),
#  ('make', 7),
#  ('covid-19"', 7),
#  ('es…', 7),
#  ('acaba', 7),
#  ('ayuda', 7),
#  ('really', 7),
#  ('health', 7),
#  ('puebla', 7),
#  ('week', 7),
#  ('over', 7),
#  ('asegura', 7),
#  ('ordenó', 7),
#  ('contaminar', 7),
#  ('https://t.co/oa8slazj…', 7),
#  ('@dios_federacion:', 7),
#  ('payaso', 7),
#  ('atiende', 7),
#  ('(covid-19)', 7),
#  ('dip.', 7),
#  ('@joseolivaresm:', 7),
#  ('desinfección', 7),
#  ('concejal', 7),
#  ('servicios', 7),
#  ('📌', 7),
#  ('𝙄𝙣𝙛𝙤́𝙧𝙢𝙖𝙩𝙚', 7),
#  ('@lucioquincioc:', 7),
#  ('dije,', 7),
#  ('disparo', 7),
#  ('exponencialmente', 7),
#  ('#venezuela,', 7),
#  ('pare...75', 7),
#  ('caso…', 7),
#  ('inicio', 7),
#  ('venezolanos', 7),
#  ('contagiarse', 7),
#  ('combate', 7),
#  ('deaths', 7),
#  ('grupo', 7),
#  ('días,', 7),
#  ('2020.', 7),
#  ('jefe', 7),
#  ('no,', 7),
#  ('año', 7),
#  ('planeta', 7),
#  ('incluyendo', 7),
#  ('objetivo', 7),
#  ('mes', 7),
#  ('top', 7),
#  ('25', 7),
#  ('mundo,', 7),
#  ('officials', 7),
#  ('rodríguez', 7),
#  ('@claudiashein', 7),
#  ('@foro_tv:', 7),
#  ('consumo', 7),
#  ('mental', 7),
#  ('mask', 7),
#  ('regional', 7),
#  ('cumpleaños', 7),
#  ('workers', 7),
#  ('death', 7),
#  ('way', 7),
#  ('día,', 7),
#  ('ministerio', 7),
#  ('diputado', 7),
#  ('comparto', 7),
#  ('inmunidad', 7),
#  ('➡️', 7),
#  ('vivo', 7),
#  ('agua', 7),
#  ('maldito', 7),
#  ('424', 7),
#  ('médica', 7),
#  ('dead', 7),
#  ('invitamos', 7),
#  ('#covid19mx', 7),
#  ('million', 7),
#  ('mexicano', 7),
#  ('then', 7),
#  ('read', 7),
#  ('miente', 7),
#  ('seguros', 7),
#  ('pleno', 7),
#  ('auge,', 7),
#  ('cobrando', 7),
#  ('exigimos', 7),
#  ('concluyó', 7),
#  ('reduce', 7),
#  ('75%', 7),
#  ('https://t.co/otd08u…', 7),
#  ('@maricelaserhdz:', 7),
#  ('re…', 7),
#  ('@escalantesv:', 7),
#  ('capacidad,', 7),
#  ('detectan', 7),
#  ('manos', 7),
#  ('insomnio', 7),
#  ('off', 7),
#  ('@enrique_clausen:', 7),
#  ('machaca', 7),
#  ('fest', 7),
#  ('definitivamente', 7),
#  ('https://t.co/twd3hgj1vu', 7),
#  ('unidos', 7),
#  ('sala', 6),
#  ('nursing', 6),
#  ('us', 6),
#  ('because', 6),
#  ('where', 6),
#  ('epidemiológico', 6),
#  ('noticia', 6),
#  ('some', 6),
#  ('50', 6),
#  ('espacios', 6),
#  ('vacunas', 6),
#  ('(@', 6),
#  ('atendiendo', 6),
#  ('instrucciones', 6),
#  ('😭', 6),
#  ('espacio', 6),
#  ('13', 6),
#  ('covid,', 6),
#  ('#coronavirusmexico', 6),
#  ('#covid2019mx', 6),
#  ('@tu_imss', 6),
#  ('ciclo', 6),
#  ('atención,', 6),
#  ('april', 6),
#  ('/', 6),
#  ('@youtube', 6),
#  ('capacidad', 6),
#  ('since', 6),
#  ('baja', 6),
#  ('california', 6),
#  ('números', 6),
#  ('normalidad', 6),
#  ('don’t', 6),
#  ('said', 6),
#  ('seminario', 6),
#  ('ca…', 6),
#  ('funambulesco,', 6),
#  ('estropeado', 6),
#  ('física', 6),
#  ('moralmente', 6),
#  ('palangrista', 6),
#  ('abyecto,', 6),
#  ('ecuador', 6),
#  ('"', 6),
#  ('parroquia', 6),
#  ('persona.', 6),
#  ('tocar', 6),
#  ('@sbsnews:', 6),
#  ('¡𝐓𝐎𝐌𝐀', 6),
#  ('𝐏𝐑𝐄𝐂𝐀𝐔𝐂𝐈𝐎́𝐍', 6),
#  ('transmitir', 6),
#  ('fácilmente', 6),
#  ('persona,', 6),
#  ('adopta…', 6),
#  ('unidad', 6),
#  ('antonio', 6),
#  ('@vpitv:', 6),
#  ('pese', 6),
#  ('prensa', 6),
#  ('dispone', 6),
#  ('posibles', 6),
#  ('comercial', 6),
#  ('them', 6),
#  ('56', 6),
#  ('rusia', 6),
#  ('diarios', 6),
#  ('@milenio:', 6),
#  ('two', 6),
#  ('@politicomx:', 6),
#  ('acumularon', 6),
#  ('visto', 6),
#  ('visitando', 6),
#  ('hospitales?', 6),
#  ('desarrollo', 6),
#  ('pedro', 6),
#  ('https:/…', 6),
#  (':', 6),
#  ('maría', 6),
#  ('abr-may:', 6),
#  ('14,', 6),
#  ('urgencias', 6),
#  ('epidemia', 6),
#  ('adultos', 6),
#  ('vuelo', 6),
#  ('rehabilitación', 6),
#  ('@sntenacional:', 6),
#  ('risk', 6),
#  ('casa,', 6),
#  ('@janosikgarciaz:', 6),
#  ('hombre', 6),
#  ('trabajos', 6),
#  ('80', 6),
#  ('‼️on', 6),
#  ('feb', 6),
#  ('13,', 6),
#  ('assembled', 6),
#  ('emergency', 6),
#  ('“contain', 6),
#  ('virus,”', 6),
#  ('begin', 6),
#  ('prep…', 6),
#  ('recuerda', 6),
#  ('were', 6),
#  ('animales', 6),
#  ('depende', 6),
#  ('invertir', 6),
#  ('afecta', 6),
#  ('@sinembargomx:', 6),
#  ('penal', 6),
#  ('deseo', 6),
#  ('paciente', 6),
#  ('🏥', 6),
#  ('tratamiento', 6),
#  ('high', 6),
#  ('other', 6),
#  ('rojo', 6),
#  ('mundial', 6),
#  ('tomar', 6),
#  ('comienza', 6),
#  ('help', 6),
#  ('@lopezdoriga:', 6),
#  ('home', 6),
#  ('need', 6),
#  ('ejecutivo', 6),
#  ('la…', 6),
#  ('diaria', 6),
#  ('residencia', 6),
#  ('prevención', 6),
#  ('🔸', 6),
#  ('red', 6),
#  ('#coahuila', 6),
#  ('#cdmx', 6),
#  ('comunicado', 6),
#  ('creó', 6),
#  ('alcalde', 6),
#  ('@gobiernomx', 6),
#  ('suma', 6),
#  ('crean', 6),
#  ('reales', 6),
#  ('@celisaguirre:', 6),
#  ('intubadas', 6),
#  ('posibilidad', 6),
#  ('informe', 6),
#  ('están…', 6),
#  ('impacto', 6),
#  ('registrado', 6),
#  ('https://t.co/sbnhlsn2xb', 6),
#  ('https://t.co/ylpb8yiv4r', 6),
#  ('#noqueremosmásmentiras.', 6),
#  ('toma', 6),
#  ('ve', 6),
#  ('creen', 6),
#  ('¿por', 6),
#  ('america', 6),
#  ('💤🕙💤', 6),
#  ('educación', 6),
#  ('@diario_supremo:', 6),
#  ('políticos', 6),
#  ('@vertientegloba1:', 6),
#  ('month', 6),
#  ('deberían', 5),
#  ('cree', 5),
#  ('fake', 5),
#  ('cadena', 5),
#  ('@c5_cdmx', 5),
#  ('little', 5),
#  ('away', 5),
#  ('camino', 5),
#  ('here', 5),
#  ('virus...', 5),
#  ('@omarfayad', 5),
#  ('mayores', 5),
#  ('hospitalizado', 5),
#  ('niño', 5),
#  ('r…', 5),
#  ('only', 5),
#  ('thing', 5),
#  ('#covid', 5),
#  ('tendencias', 5),
#  ('ios', 5),
#  ('incluye', 5),
#  ('#puebla', 5),
#  ('extraño', 5),
#  ('fotos', 5),
#  ('ignorancia', 5),
#  ('pico', 5),
#  ('necesita', 5),
#  ('conocido', 5),
#  ('•', 5),
#  ('análisis', 5),
#  ('trae', 5),
#  ('entienden', 5),
#  ('país,', 5),
#  ('homes', 5),
#  ('jajaja', 5),
#  ('mamá', 5),
#  ('andan', 5),
#  ('📝', 5),
#  ('debería', 5),
#  ('ventiladores', 5),
#  ('@juan_revenga:', 5),
#  ('olvidar', 5),
#  ('menús', 5),
#  ('hospitala…', 5),
#  ('shows', 5),
#  ('lot', 5),
#  ('llegar', 5),
#  ('privado', 5),
#  ('noticias', 5),
#  ('scherer', 5),
#  ('white', 5),
#  ('acumuladas', 5),
#  ("i'm", 5),
#  ('infectados', 5),
#  ('using', 5),
#  ('área', 5),
#  ('oportunidad', 5),
#  ('etapa', 5),
#  ('sale', 5),
#  ('españa', 5),
#  ('vidas', 5),
#  ('ht…', 5),
#  ('jajajaja', 5),
#  ('resfriado', 5),
#  ('hasta…', 5),
#  ('mayo:', 5),
#  ('misión', 5),
#  ('bella', 5),
#  ('recomendó', 5),
#  ('shown', 5),
#  ('possible', 5),
#  ...]
